# %% [markdown]
# <a href="https://colab.research.google.com/github/ammwill/Prograx/blob/main/Prueba3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
personas=[]
sw=1
while sw==1:
  print("---------------------------------------------------------------")
  print("Bienvenido a Totem Registro Civil")
  print("")
  print("")
  print("---------------------------------------------------------------")
  print("Menú Principal")
  print("")
  print("\t 1. Grabar Información de una persona")
  print("\t 2. Buscar Información de una persona")
  print("\t 3. Imprimir Certificado")
  print("\t 4. Borrar información de una persona")
  print("\t 5. Salir")
  print("---------------------------------------------------------------")
  print("")
  opcion=input("\t Por favor indique la opción que desea:  \t")
  if opcion==1:
    print("\t Usted ha solicitado grabar los datos")
    while s1==0:
      rut=input("\t Por favor indique su rut sin puntos y con guión (si termina en K, reemplácelo por un 0):  \t")
      d1=int(rut[0:1])
      d2=int(rut[1:2])
      d3=int(rut[2:3])
      d4=int(rut[3:4])
      d5=int(rut[4:5])
      d6=int(rut[5:6])
      d7=int(rut[6:7])
      d8=int(rut[7:8])
      d9=int(rut[9:10])
      lista_rut=[d1,d2,d3,d4,d5,d6,d7,d8]
      lista_rut.reverse()
      multiplicadores=[2,3,4,5,6,7,2,3]
      product = [x*y for x,y in zip(lista_rut,multiplicadores)]
      suma=sum(product)
      div1=int(suma/11)
      mult1=div1*11
      rest1=suma-mult1
      rest2=11-rest1
      if rest2==d9:
        print("\t Rut correcto")
      elif rest2==10 and d9==0:
        print("\t Rut correcto")
      elif rest2==11 and d9==0:
        print("\t Rut correcto")
      else:
        print("\t Rut Incorrecto. Ingrese nuevamente sus datos")
        sw=0
      nombre=input("\t Ingrese su nombre: \t")
      edad=input("\t Ingrese su edad: \t")
      pais=input("\t Ingrese su país de nacimiento: \t")
      ciudad=input("\t Ingrese su ciudad de nacimiento: \t")
      persona = {
        "rut": rut,
        "nombre": nombre,
        "edad": edad,
        "pais": pais,
        "ciudad": ciudad
        }
      personas.append(persona)
      print("\t Datos de la persona grabados correctamente.")
      opcion2=input("Desea realizar otra acción? Ingrese '1' si desea otra acción o '2' Si prefiere Salir: \t")
      if opcion2==1:
        print("¿Qué otra acción desea hacer?")
        sw=0
      if opcion2==2:
        print("Gracias. Vuelva pronto.")
        sw=1
  if opcion==2:
    rut=input("\t Por favor indique su rut sin puntos y con guión (si termina en K, reemplácelo por un 0):  \t")
    if persona["rut"]==rut:
     print("Información de la persona:")
     print(f"RUT: {persona['rut']}")
     print(f"Nombre: {persona['nombre']}")
     print(f"Edad: {persona['edad']}")
     print(f"País de nacimiento: {persona['pais_nacimiento']}")
     print(f"Ciudad de nacimiento: {persona['ciudad_nacimiento']}")
     if persona['pais_nacimiento'] == 'chile':
      print("La persona pertenece al país de Chile.")
     opcion3=input("Desea realizar otra acción? Ingrese '1' si desea otra acción o '2' Si prefiere Salir: \t")
     if opcion3==1:
       print("¿Qué otra acción desea hacer?")
       sw=0
     if opcion3==2:
        print("Gracias. Vuelva pronto.")
        sw=1
  if opcion==3:
   rut=input("\t Por favor indique su rut sin puntos y con guión (si termina en K, reemplácelo por un 0):  \t")
   certificado=input("\t Ingrese tipo certificado:  \t")
   if persona["rut"] == rut:
     print(f"RUT de la persona: {persona['rut']}")
     print(f"Nombre de la persona: {persona['nombre']}")
     print(f"Datos adicionales del certificado {certificado}")
     opcion4=input("Desea realizar otra acción? Ingrese '1' si desea otra acción o '2' Si prefiere Salir: \t")
     if opcion4==1:
       print("¿Qué otra acción desea hacer?")
       sw=0
     if opcion4==2:
       print("Gracias. Vuelva pronto.")
       sw=1
  if opcion==4:
    if persona["rut"] == rut:
      personas.remove(persona)
      print("La persona ha sido eliminada correctamente.")
      opcion5=input("Desea realizar otra acción? Ingrese '1' si desea otra acción o '2' Si prefiere Salir: \t")
      if opcion5==1:
        print("¿Qué otra acción desea hacer?")
        sw=0
      if opcion5==2:
        print("Gracias. Vuelva pronto.")
        sw=1
if opcion==5:
  print("")
  print("Gracias, vuelva pronto")

print("Gracias vuelva pronto.")
