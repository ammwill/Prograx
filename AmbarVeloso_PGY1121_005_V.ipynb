# %% [markdown]
# <a href="https://colab.research.google.com/github/ammwill/Prograx/blob/main/AmbarVeloso_PGY1121_005_V.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pisos=10
depas=4
vendidos = []
compradores = {}
precios_venta = {
    'A': 3800,
    'B': 3000,
    'C': 2800,
    'D': 3500,
    }

def disponibilidad(depto):
    if depto in vendidos:
        return False
    return True

def comprar_departamento():
    depto=input("Por favor ingrese el departamento a comprar. Primero tipo y luego piso (EJ: A9): ")
    tipo_departamento = depto[0]
    piso_departamento = int(depto[1])

    if not disponibilidad(depto):
        print("El departamento no está disponible.")
        return

    rut = input("Por favor ingrese su RUT sin puntos ni guion: ")

    vendidos.append(depto)
    compradores[depto]=rut
    print("¡Felicitaciones, ya es propietario de su nueva vivienda!")
    if depto=="A1":
      A1="X"
    else:
      A1=" "
    if depto=="B1":
      B1="X"
    else:
      B1=" "
    if depto=="C1":
      C1="X"
    else:
      C1=" "
    if depto=="D1":
      D1="X"
    else:
      D1=" "
    if depto=="A2":
      A2="X"
    else:
      A2=" "
    if depto=="B2":
      B2="X"
    else:
      B2=" "
    if depto=="C2":
      C2="X"
    else:
      C2=" "
    if depto=="D2":
      D2="X"
    else:
      D2=" "
    if depto=="A3":
      A3="X"
    else:
      A3=" "
    if depto=="B3":
      B3="X"
    else:
      B3=" "
    if depto=="C3":
      C3="X"
    else:
      C3=" "
    if depto=="D3":
      D3="X"
    else:
      D3=" "
    if depto=="A4":
      A4="X"
    else:
      A4=" "
    if depto=="B4":
      B4="X"
    else:
      B4=" "
    if depto=="C4":
      C4="X"
    else:
      C4=" "
    if depto=="D4":
      D4="X"
    else:
      D4=" "
    if depto=="A5":
      A5="X"
    else:
      A5=" "
    if depto=="B5":
      B5="X"
    else:
      B5=" "
    if depto=="C5":
      C5="X"
    else:
      C5=" "
    if depto=="D5":
      D5="X"
    else:
      D5=" "
    if depto=="A6":
      A6="X"
    else:
      A6=" "
    if depto=="B6":
      B6="X"
    else:
      B6=" "
    if depto=="C6":
      C6="X"
    else:
      C6=" "
    if depto=="D6":
      D6="X"
    else:
      D6=" "
    if depto=="A7":
      A7="X"
    else:
      A7=" "
    if depto=="B7":
      B7="X"
    else:
      B7=" "
    if depto=="C7":
      C7="X"
    else:
      C7=" "
    if depto=="D7":
      D7="X"
    else:
      D7=" "
    if depto=="A8":
      A8="X"
    else:
      A8=" "
    if depto=="B8":
      B8="X"
    else:
      B8=" "
    if depto=="C8":
      C8="X"
    else:
      C8=" "
    if depto=="D8":
      D8="X"
    else:
      D8=" "
    if depto=="A9":
      A9="X"
    else:
      A9=" "
    if depto=="B9":
      B9="X"
    else:
      B9=" "
    if depto=="C9":
      C9="X"
    else:
      C9=" "
    if depto=="D9":
      D9="X"
    else:
      D9=" "
    if depto=="A10":
      A10="X"
    else:
      A10=" "
    if depto=="B10":
      B10="X"
    else:
      B10=" "
    if depto=="C10":
      C10="X"
    else:
      C10=" "
    if depto=="D10":
      D10="X"
    else:
      D10=" "

    print("\t Piso \t A | \t B | \t C | \t D")
    print(f"\t 1 \t {A1} | \t {B1} | \t {C1} | \t {D1}")
    print(f"\t 2 \t {A2} | \t {B2} | \t {C2} | \t {D2}")
    print(f"\t 3 \t {A3} | \t {B3} | \t {C3} | \t {D3}")
    print(f"\t 4 \t {A4} | \t {B4} | \t {C4} | \t {D4}")
    print(f"\t 5 \t {A5} | \t {B5} | \t {C5} | \t {D5}")
    print(f"\t 6 \t {A6} | \t {B6} | \t {C6} | \t {D6}")
    print(f"\t 7 \t {A7} | \t {B7} | \t {C7} | \t {D7}")
    print(f"\t 8 \t {A8} | \t {B8} | \t {C8} | \t {D8}")
    print(f"\t 9 \t {A9} | \t {B9} | \t {C9} | \t {D9}")
    print(f"\t 10 \t {A10} | \t {B10} | \t {C10} | \t {D10}")

def disponibles():
    print("Departamentos en stock:")
    for piso in range(1, pisos + 1):
        for depto in ['A', 'B', 'C', 'D']:
            num_depto = depto + str(piso)
            if num_depto in vendidos:
                print(f"Departamento {num_depto} - No Disponible")

            else:
                print(f"Departamento {num_depto} - En Stock")

def lista_compradores():
    print("Listado de compradores:")
    for depto, rut in sorted(compradores.items(), key=lambda x: x[1]):
        print(f"Departamento {depto}: {rut}")



sw=0

while sw==0:
    print("--------------------------------------")
    print("\t ¡Bienvenido a Inmobiliaria CASA FELIZ!")
    print("")
    print("\t 1. Comprar departamento ")
    print("\t 2. Mostrar departamentos disponibles")
    print("\t 3. Ver listado de compradores")
    print("\t 4. Mostrar ganancias totales")
    print("\t 5. Salir")
    print("")
    op=input("Ingrese opción: ")
    if op=="1":
      comprar=comprar_departamento()
      sw=0
    if op=="2":
      disponibilidad=disponibles()
      sw=0
    if op=="3":
      listado=lista_compradores()
      sw=0
    else:
      print("Muchas gracias por su preferencia, ¡vuelva pronto!")
      sw=1
# Out:
# --------------------------------------
# 	 ¡Bienvenido a Inmobiliaria CASA FELIZ!
#
# 	 1. Comprar departamento
# 	 2. Mostrar departamentos disponibles
# 	 3. Ver listado de compradores
# 	 4. Mostrar ganancias totales
# 	 5. Salir
#
# Ingrese opción: 3
# Listado de compradores:
# --------------------------------------
# 	 ¡Bienvenido a Inmobiliaria CASA FELIZ!
#
# 	 1. Comprar departamento
# 	 2. Mostrar departamentos disponibles
# 	 3. Ver listado de compradores
# 	 4. Mostrar ganancias totales
# 	 5. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-29112c8dc3a7> in <cell line: 222>()
#     230     print("\t 5. Salir")
#     231     print("")
# --> 232     op=input("Ingrese opción: ")
#     233     if op=="1":
#     234       comprar=comprar_departamento()
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
